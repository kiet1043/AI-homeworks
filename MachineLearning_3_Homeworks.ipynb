# %% [markdown]
# <a href="https://colab.research.google.com/github/kiet1043/AI-homeworks/blob/main/MachineLearning_3_Homeworks.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **IRIS**

# %%
import pandas as pd
url_iris = 'iris.csv'
data_iris = pd.read_csv(url_iris)
import matplotlib.pyplot as plt
data_iris.hist()
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
correlation_iris = data.corr()
print(correlation_iris)
import seaborn as sns
sns.heatmap(correlation_iris, annot = True)
# Out:
#               sepal.length  sepal.width  petal.length  petal.width
# sepal.length      1.000000    -0.117570      0.871754     0.817941
# sepal.width      -0.117570     1.000000     -0.428440    -0.366126
# petal.length      0.871754    -0.428440      1.000000     0.962865
# petal.width       0.817941    -0.366126      0.962865     1.000000
# <Axes: >

# %%
datairis.plot(kind = 'scatter', x = 'petal.width', y = 'petal.length', figsize=(9,9), color = 'black')
# Out:
# /usr/local/lib/python3.9/dist-packages/pandas/plotting/_matplotlib/core.py:1114: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   scatter = ax.scatter(
# <Axes: xlabel='petal.width', ylabel='petal.length'>

# %%
#Mô hình bậc 1
from sklearn import linear_model
model_iris = linear_model.LinearRegression()
X = pd.DataFrame(data_iris['petal.width'])
model_iris.fit(X, y = data_iris['petal.length'])
print('Intercept của mô hình: ', model_iris.intercept_)
print('Coeffient của mô hình: ', model_iris.coef_)
print('Độ chính xác của mô hình: ', modeliris.score(X,y = data_iris['petal.length']))
datairis.plot(kind = 'scatter', x = 'petal.width', y = 'petal.length', figsize=(9,9), color = 'black')
y_pred = modeliris.predict(X)
plt.plot(X,y_pred, color = 'blue')
# Out:
# Intercept của mô hình:  1.0835580328505112
# Coeffient của mô hình:  [2.2299405]
# Độ chính xác của mô hình:  0.9271098389904927
# /usr/local/lib/python3.9/dist-packages/pandas/plotting/_matplotlib/core.py:1114: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   scatter = ax.scatter(

# %%
#Mô hình bậc 10
from sklearn import linear_model
model_abalone3 = linear_model.LinearRegression()
X = pd.DataFrame([data_iris['petal.width'], data_iris['petal.width']**2, data_iris['petal.width']**3, data_iris['petal.width']**4,
                  data_iris['petal.width']**5, data_iris['petal.width']**6,data_iris['petal.width']**7, data_iris['petal.width']**8,
                  data_iris['petal.width']**9, data_iris['petal.width']**10]).T
model_abalone3.fit(X, y = data_iris['petal.length'])
print('Intercept của mô hình: ', model_abalone3.intercept_)
print('Coeffient của mô hình: ', model_abalone3.coef_)
print('Độ chính xác của mô hình: ', 
      model_abalone3.score(X,y = data_iris['petal.length']))

import numpy as np
range = np.arange(0,2.7,0.1)
data_iris.plot(kind = 'scatter', x = 'petal.width', y = 'petal.length', figsize=(9,9),
                 color = 'black', xlim=(0,2.7))
predictor = pd.DataFrame([range, range**2, range**3, range**4, range**5,
                          range**6, range**7, range**8, range**9, range**10]).T
y_pred = model_abalone3.predict(X = predictor)
plt.plot(range,y_pred, color = 'blue')
# Out:
# Intercept của mô hình:  2.563515728097817
# Coeffient của mô hình:  [  -27.66596325   238.9875364  -1002.45826142  2340.80724768
#  -3252.69458848  2807.53650465 -1521.72686204   504.14070248
#    -93.31740232     7.39509026]
# Độ chính xác của mô hình:  0.9574425954634327
# /usr/local/lib/python3.9/dist-packages/pandas/plotting/_matplotlib/core.py:1114: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   scatter = ax.scatter(
# /usr/local/lib/python3.9/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(

# %% [markdown]
# **ABALONE**

# %%
import pandas as pd
import matplotlib.pyplot as plt
url_abalon = 'abalone.csv'
data_abalone = pd.read_csv(url_abalon)
data_abalone.hist()
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
correlation_abalone = data_abalone.corr()
print(correlation_abalone)
import seaborn as sns
sns.heatmap(correlation_abalone, annot = True)
# Out:
#                   Length  Diameter    Height  Whole weight  Shucked weight  \
# Length          1.000000  0.986812  0.827554      0.925261        0.897914
# Diameter        0.986812  1.000000  0.833684      0.925452        0.893162
# Height          0.827554  0.833684  1.000000      0.819221        0.774972
# Whole weight    0.925261  0.925452  0.819221      1.000000        0.969405
# Shucked weight  0.897914  0.893162  0.774972      0.969405        1.000000
# Viscera weight  0.903018  0.899724  0.798319      0.966375        0.931961
# Shell weight    0.897706  0.905330  0.817338      0.955355        0.882617
# Rings           0.556720  0.574660  0.557467      0.540390        0.420884
#
#                 Viscera weight  Shell weight     Rings
# Length                0.903018      0.897706  0.556720
# Diameter              0.899724      0.905330  0.574660
# Height                0.798319      0.817338  0.557467
# Whole weight          0.966375      0.955355  0.540390
# ...

# %%
data_abalone.plot(kind = 'scatter', x = 'Shucked weight', y = 'Whole weight', figsize=(9,9), color = 'black')
# Out:
# /usr/local/lib/python3.9/dist-packages/pandas/plotting/_matplotlib/core.py:1114: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   scatter = ax.scatter(
# <Axes: xlabel='Shucked weight', ylabel='Whole weight'>

# %%
#Mô hình bậc 1
from sklearn import linear_model
model_abalone = linear_model.LinearRegression()
X = pd.DataFrame(data_abalone['Shucked weight'])
model_abalone.fit(X, y = data_abalone['Whole weight'])
print('Intercept của mô hình: ', model_abalone.intercept_)
print('Coeffient của mô hình: ', model_abalone.coef_)
print('Độ chính xác của mô hình: ', model_abalone.score(X,y = data_abalone['Whole weight']))
data_abalone.plot(kind = 'scatter', x = 'Shucked weight', y = 'Whole weight', figsize=(9,9), color = 'black')
y_pred = model_abalone.predict(X)
plt.plot(X,y_pred, color = 'blue')
# Out:
# Intercept của mô hình:  0.05907227403881188
# Coeffient của mô hình:  [2.14173488]
# Độ chính xác của mô hình:  0.9397469394863921
# /usr/local/lib/python3.9/dist-packages/pandas/plotting/_matplotlib/core.py:1114: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   scatter = ax.scatter(

# %%
#Mô hình bậc 10
from sklearn import linear_model
model_abalone3 = linear_model.LinearRegression()
X = pd.DataFrame([data_abalone['Shucked weight'], data_abalone['Shucked weight']**2, data_abalone['Shucked weight']**3, data_abalone['Shucked weight']**4,
                  data_abalone['Shucked weight']**5, data_abalone['Shucked weight']**6,data_abalone['Shucked weight']**7, data_abalone['Shucked weight']**8,
                  data_abalone['Shucked weight']**9, data_abalone['Shucked weight']**10]).T
model_abalone3.fit(X, y = data_abalone['Whole weight'])
print('Intercept của mô hình: ', model_abalone3.intercept_)
print('Coeffient của mô hình: ', model_abalone3.coef_)
print('Độ chính xác của mô hình: ', 
      model_abalone3.score(X,y = data_abalone['Whole weight']))

import numpy as np
range = np.arange(0,1.6,0.1)
data_abalone.plot(kind = 'scatter', x = 'Shucked weight', y = 'Whole weight', figsize=(9,9),
                 color = 'black', xlim=(0,1.6))
predictor = pd.DataFrame([range, range**2, range**3, range**4, range**5,
                          range**6, range**7, range**8, range**9, range**10]).T
y_pred = model_abalone3.predict(X = predictor)
plt.plot(range,y_pred, color = 'blue')
# Out:
# Intercept của mô hình:  -0.008442026696976912
# Coeffient của mô hình:  [    3.36816887   -20.53934847   182.86288168  -832.61312278
#   2155.27622754 -3366.66419422  3227.57341424 -1854.26823221
#    584.81279235   -77.72133516]
# Độ chính xác của mô hình:  0.9446194678328996
# /usr/local/lib/python3.9/dist-packages/pandas/plotting/_matplotlib/core.py:1114: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   scatter = ax.scatter(
# /usr/local/lib/python3.9/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(

# %% [markdown]
# **USA_HOUSING**

# %%
import pandas as pd
import matplotlib.pyplot as plt
url_crab = 'data_crab.csv'
data_crab = pd.read_csv(url_crab)
data_crab.hist()
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
correlation_crab = data_crab.corr()
print(correlation_crab)
import seaborn as sns
sns.heatmap(correlation_crab, annot = True)
# Out:
#           index        FL        RW        CL        CW        BD
# index  1.000000  0.862876  0.840040  0.911436  0.928248  0.864459
# FL     0.862876  1.000000  0.906988  0.978842  0.964956  0.987627
# RW     0.840040  0.906988  1.000000  0.892743  0.900402  0.889205
# CL     0.911436  0.978842  0.892743  1.000000  0.995023  0.983204
# CW     0.928248  0.964956  0.900402  0.995023  1.000000  0.967812
# BD     0.864459  0.987627  0.889205  0.983204  0.967812  1.000000
# <Axes: >

# %%
data_crab.plot(kind = 'scatter', x = 'CW', y = 'BD', figsize=(9,9), color = 'black')
# Out:
# /usr/local/lib/python3.9/dist-packages/pandas/plotting/_matplotlib/core.py:1114: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   scatter = ax.scatter(
# <Axes: xlabel='CW', ylabel='BD'>

# %%
#Mô hình bậc 1
from sklearn import linear_model
model_crab = linear_model.LinearRegression()
X = pd.DataFrame(data_crab['CW'])
model_crab.fit(X, y = data_crab['BD'])
print('Intercept của mô hình: ', model_crab.intercept_)
print('Coeffient của mô hình: ', model_crab.coef_)
print('Độ chính xác của mô hình: ', model_crab.score(X,y = data_crab['BD']))
data_crab.plot(kind = 'scatter', x = 'CW', y = 'BD', figsize=(9,9), color = 'black')
y_pred = model_crab.predict(X)
plt.plot(X,y_pred, color = 'blue')
# Out:
# Intercept của mô hình:  -1.3020462965538737
# Coeffient của mô hình:  [0.42105607]
# Độ chính xác của mô hình:  0.9366593985807309
# /usr/local/lib/python3.9/dist-packages/pandas/plotting/_matplotlib/core.py:1114: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   scatter = ax.scatter(

# %%
#Mô hình bậc 10
from sklearn import linear_model
model_crab10 = linear_model.LinearRegression()
X = pd.DataFrame([data_crab['CW'], data_crab['CW']**2, data_crab['CW']**3, data_crab['CW']**4,
                  data_crab['CW']**5, data_crab['CW']**6,data_crab['CW']**7, data_crab['CW']**8,
                  data_crab['CW']**9, data_crab['CW']**10]).T
model_crab10.fit(X, y = data_crab['BD'])
print('Intercept của mô hình: ', model_crab10.intercept_)
print('Coeffient của mô hình: ', model_crab10.coef_)
print('Độ chính xác của mô hình: ', 
      model_crab10.score(X,y = data_crab['BD']))

import numpy as np
range = np.arange(15,55,0.1)
data_crab.plot(kind = 'scatter', x = 'CW', y = 'BD', figsize=(9,9), color = 'black', xlim=(15,55))
predictor = pd.DataFrame([range, range**2, range**3, range**4, range**5,
                          range**6, range**7, range**8, range**9, range**10]).T
y_pred = model_crab10.predict(X = predictor)
plt.plot(range,y_pred, color = 'blue')
# Out:
# Intercept của mô hình:  10.00616133358714
# Coeffient của mô hình:  [-5.89764080e-07 -1.31616143e-05 -1.57695322e-04 -1.00376502e-03
#   1.48455991e-04 -9.05144610e-06  2.93485634e-07 -5.33775847e-09
#   5.15898436e-11 -2.06859171e-13]
# Độ chính xác của mô hình:  0.9390311159726341
# /usr/local/lib/python3.9/dist-packages/pandas/plotting/_matplotlib/core.py:1114: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   scatter = ax.scatter(
# /usr/local/lib/python3.9/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
